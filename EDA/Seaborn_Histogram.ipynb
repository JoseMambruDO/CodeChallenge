# %%
# Standard
import numpy as np
import pandas as pd

# %%
# Stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
ds1 = np.random.randn(100)

# %%
plt.hist(ds1)
# Out:
# (array([ 2.,  3.,  4., 12., 16., 28., 17., 12.,  3.,  3.]),
#  array([-2.77670786, -2.28107132, -1.78543477, -1.28979823, -0.79416168,
#         -0.29852514,  0.19711141,  0.69274796,  1.1883845 ,  1.68402105,
#          2.17965759]),
#  <BarContainer object of 10 artists>)

# %%
ds2 = np.random.randn(80)

plt.hist(ds2,color='green')
# Out:
# (array([ 4.,  6., 13., 22., 11., 13.,  4.,  3.,  3.,  1.]),
#  array([-2.08520213, -1.60974156, -1.13428098, -0.65882041, -0.18335983,
#          0.29210075,  0.76756132,  1.2430219 ,  1.71848247,  2.19394305,
#          2.66940363]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ds1, color='indianred',alpha=0.5,bins=20)
plt.hist(ds2, color='cyan',alpha=0.5,bins=20)
# Out:
# (array([ 2.,  2.,  5.,  1.,  8.,  5.,  9., 13.,  6.,  5.,  8.,  5.,  1.,
#          3.,  0.,  3.,  3.,  0.,  0.,  1.]),
#  array([-2.08520213, -1.84747185, -1.60974156, -1.37201127, -1.13428098,
#         -0.89655069, -0.65882041, -0.42109012, -0.18335983,  0.05437046,
#          0.29210075,  0.52983103,  0.76756132,  1.00529161,  1.2430219 ,
#          1.48075219,  1.71848247,  1.95621276,  2.19394305,  2.43167334,
#          2.66940363]),
#  <BarContainer object of 20 artists>)

# %%
dt1 = np.random.randn(1000)
dt2 = np.random.randn(1000)

# %%
sns.jointplot(x=dt1,y=dt2)

# %%
sns.jointplot(x=dt1,y=dt2,kind='hex')
